# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel(r"C:\Users\Jishanth M I\Downloads\DS1_C5_S2_Income_Data_Challenge.xlsx")
data
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %% [markdown]
# # Task 1

# %%
#Define a function to identify the data type of the columns as categorical or numerical.
#Separate the names of the categorical and numerical columns and save them into two different lists


data_cat=data.select_dtypes(include='object')
print(data_cat.columns)

data_con=data.select_dtypes(include='number')
print(data_con.columns)
# Out:
# Index(['WorkClass', 'Education', 'Marital_Status', 'Occupation',
#        'Relationship', 'Gender', 'Native_Country', 'Income_Bracket'],
#       dtype='object')
# Index(['Age', 'Education_Num', 'Hours_Per_Week'], dtype='object')

# %% [markdown]
# # Task 2

# %%
#Perform bivariate and multivariate analysis on categorical columns (identified in Task 1) with the help of appropriate graphs/charts.


# Bivariate Analysis (Categorical vs. Categorical)
plt.figure(figsize=(10,6))
pd.crosstab(index=data['WorkClass'],columns=data['Marital_Status']).plot(kind='bar')
pd.crosstab(index=data['WorkClass'],columns=data['Gender']).plot(kind='bar')


# multivariate analysis
plt.figure(figsize=(10,6))
sb.barplot(x=data['Marital_Status'],y=data['Age'],hue=data['WorkClass'])
plt.xticks(rotation=90)
plt.show()
plt.figure(figsize=(10,6))
sb.barplot(x=data['Education'],y=data['Age'],hue=data['WorkClass'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Task 3

# %%
#Perform bivariate and multivariate analysis on numarical columns (identified in Task 1) with the help of appropriate graphs/charts.

# Bivariate Analysis (numarical vs. numarical)
sb.lineplot(x=data['Education_Num'],y=data['Hours_Per_Week'])

# multivariate analysis
sb.pairplot(data,vars=['Age', 'Education_Num', 'Hours_Per_Week'],diag_kind='kde',kind='scatter')

# %%
data_con.columns
# Out:
# Index(['Age', 'Education_Num', 'Hours_Per_Week'], dtype='object')
